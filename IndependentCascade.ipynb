# %%
#!/usr/bin/python
import operator
from dgraph import randomDirectGraph as randDGraph
from dgraph import countTriangles as ctD
from lesson4 import topk
from lesson4 import betweenness
from lesson5 import eigenvector_centrality as ec
from dgraph import diameter
from dgraph import readGraph
from dgraph import Page_Rank as pr
from dgraph import fill_incoming as fi
from dgraph import Independent_Cascade as ic
# import networkx as nx

# %%
# g = randDGraph(500, 0.1)
seed = 100
g = readGraph('wiki-Vote.txt')
fi(g)
print 'Incoming edges stored'
# Out:
# Incoming edges stored

# %%
# g = {0: [2, 3, 4], 1: [0, 2, 3], 2: [1], 3: [0, 4], 4: [0]}
# print 'Nodes: ', len(g.keys())
# print 'Diameter: ', diameter(g)
print 'Page Rank execution...'
# print 'Triangles: ', ctD(g)
pagerank, iterations, err = pr(g, alpha=1.0e-5, eps=1.0e-8) # alpha = 0.00001
print iterations, ' iterations. Error:', err
top_pr = [a for a,b in topk(pagerank, seed)]
# Out:
# Incoming edges stored
# Page Rank execution...
# 120  iterations. Error: 7.82914664494e-09

# %%
print 'Independent Cascade'
# Page Rank Seed
adopters, haters, steps = ic(g, top_pr)
print 'Independent Cascade Model: TOP %d Page Rank' % seed
print 'Final Adopters:', len(adopters)
print 'Final Haters:', len(haters)
print '# Iterations:', steps
# Out:
# Independent Cascade
# Independent Cascade Model: TOP 100 Page Rank
# Final Adopters: 271
# Final Haters: 6844
# # Iterations: 4

# %%
print 'Eigenvector Centrality'
cscores, diffsum = ec(g)
top_eigenc = [a for a, b in topk(cscores, seed)]
# Out:
# Eigenvector Centrality

# %%
# Eigenvector Seed
adopters, haters, steps = ic(g, top_eigenc)
print 'Independent Cascade Model: TOP %d Eigenvector' % seed
print 'Final Adopters:', len(adopters)
print 'Final Haters:', len(haters)
print '# Iterations:', steps
# Out:
# Independent Cascade Model: TOP 100 Eigenvector
# Final Adopters: 570
# Final Haters: 6545
# # Iterations: 5

# %%
print 'Betweennes centrality'
bet = betweenness(g)
top_bet = [a for a, b in topk(bet, seed)]
# Out:
# Betweennes centrality

# %%
# Betweennes Seed
adopters, haters, steps = ic(g, top_bet)
print 'Independent Cascade Model: TOP %d Betweennes' % seed
print 'Final Adopters:', len(adopters)
print 'Final Haters:', len(haters)
print '# Iterations:', steps
# Out:
# Independent Cascade Model: TOP 100 Betweennes
# Final Adopters: 448
# Final Haters: 6667
# # Iterations: 4

# %%
print topk(pagerank, seed)
print '========================='*4
print topk(cscores, seed)
print '========================='*4
print topk(bet, seed)
# Out:
# [('6634', 1.0), ('6946', 0.5388829742179682), ('8042', 0.5230344957992401), ('8163', 0.4887366607897079), ('2625', 0.3314867334876216), ('2398', 0.31630726222933503), ('15', 0.2985428096247973), ('4037', 0.28309045412195605), ('5412', 0.2718476670407871), ('7632', 0.2495534172576986), ('4335', 0.24051201916965545), ('4191', 0.22382771317881198), ('2066', 0.21404847327727297), ('6832', 0.2112141525343718), ('7553', 0.20973036895854635), ('4828', 0.2087867682526709), ('737', 0.20851896824199703), ('3089', 0.20387928242708653), ('4712', 0.19982431746815038), ('7620', 0.19520111816098712), ('5233', 0.19494708172509662), ('3084', 0.19072954024787728), ('4310', 0.19018762156855715), ('4875', 0.19006403745590061), ('7092', 0.18795337378361943), ('3456', 0.1879514324638424), ('5254', 0.1850701064517192), ('2328', 0.18456166392791729), ('1297', 0.18291201879304114), ('2746', 0.1813343838329189), ('3334', 0.17432781851548393), ('3352', 0.17366025774465), ('4735', 0.17289169919566819), ('2859', 0.17266295060820375), ('1549', 0.16641886489038885), ('5404', 0.16559306694998407), ('5484', 0.16442066294354432), ('762', 0.16334891006674665), ('2565', 0.16042825520976892), ('5123', 0.160362725559422), ('7862', 0.1549787515692787), ('6334', 0.1540741983236654), ('2535', 0.1521414193485597), ('5079', 0.1499776617200356), ('3459', 0.14962262764297687), ('4400', 0.14878162196399647), ('7882', 0.14364706340190433), ('5563', 0.14359818579084743), ('3898', 0.14315222784489973), ('3873', 0.14004411855437363), ('5423', 0.13899503629057505), ('2657', 0.13233537258189593), ('3897', 0.13183018482065112), ('3976', 0.13111860447126159), ('7809', 0.12851886571971785), ('4536', 0.12789823850604173), ('7699', 0.12751526775806227), ('4798', 0.12614249998228766), ('3562', 0.12531762228663704), ('3238', 0.12508836638570398), ('4981', 0.12495999463313977), ('1754', 0.12420794557035483), ('3568', 0.12391217204038683), ('3117', 0.12339578045735368), ('6006', 0.1232321823220788), ('3962', 0.12270727114353623), ('6914', 0.12257325687005757), ('3034', 0.12177585740963145), ('2958', 0.12146978335184216), ('4531', 0.12076370684883408), ('4661', 0.12047135168014016), ('4666', 0.11852840155333935), ('1211', 0.11826121669572238), ('4983', 0.11659731301644319), ('2651', 0.11556528949807338), ('5022', 0.1150091252993733), ('5459', 0.11377097488138542), ('5210', 0.11352829155768321), ('5605', 0.11335582900793521), ('2576', 0.11050621662954799), ('8294', 0.10776635058631225), ('2654', 0.10750394673429571), ('5800', 0.10727468667531583), ('4071', 0.10712519499126183), ('2237', 0.10679734152270615), ('3498', 0.10642543905179501), ('3260', 0.10582374815253207), ('7961', 0.10546655273309306), ('2585', 0.10503363318698952), ('7890', 0.1042363055797285), ('6784', 0.10371601523852646), ('993', 0.10271338800908446), ('7414', 0.10238848520747089), ('6004', 0.10201015741573977), ('825', 0.10186051372530676), ('3394', 0.1016498243508956), ('4827', 0.10123327854813559), ('6414', 0.10121147879639435), ('3005', 0.10106283595521345), ('5002', 0.10073474351516842)]
# ====================================================================================================
# [('766', 1.0), ('2565', 0.9525850461414795), ('1549', 0.9182199347235122), ('11', 0.9138297303398801), ('457', 0.8426858238682075), ('2688', 0.8394548941398529), ('1166', 0.8056161617338835), ('1151', 0.6934458051242806), ('311', 0.5961267031402888), ('813', 0.5698954191237867), ('2485', 0.5435156375501641), ('1374', 0.5261804705681015), ('2967', 0.5055128132498681), ('1133', 0.5029512433444207), ('988', 0.5008678937348323), ('1608', 0.4937090043125878), ('24', 0.4936156934101135), ('2237', 0.47499656671881674), ('3352', 0.46477217275461247), ('789', 0.44421333594006135), ('173', 0.44095631272651975), ('2651', 0.43632862845521886), ('3453', 0.43489577626509085), ('1305', 0.43468910627335006), ('993', 0.4344931933694907), ('2972', 0.4271103600192239), ('2871', 0.4254584849934877), ('36', 0.41261947620938777), ('784', 0.4116263398673324), ('2326', 0.41062215800183294), ('2328', 0.40860407252068653), ('306', 0.4071584999845274), ('1098', 0.4030572626070811), ('122', 0.3964894874928079), ('722', 0.39110795703523565), ('68', 0.3793167812941475), ('3026', 0.3684326232748231), ('1496', 0.3673541818595006), ('996', 0.3663593964215532), ('3456', 0.3660086862600961), ('3032', 0.3652964519236963), ('1972', 0.36180656714058845), ('2713', 0.36179530019500805), ('3641', 0.35856150129282555), ('3449', 0.35326679095527913), ('2658', 0.35241228958549725), ('1210', 0.3489758287108345), ('3447', 0.3486452233584783), ('4967', 0.34423359104164475), ('1319', 0.3419712213563179), ('310', 0.3357662523326836), ('879', 0.3345962877166039), ('3787', 0.3339393487066297), ('825', 0.33011246225618945), ('600', 0.32648315273891143), ('826', 0.32633220138359126), ('3394', 0.3251657197030084), ('3028', 0.3114215145636528), ('2297', 0.31032548726345865), ('1542', 0.3087190122526794), ('5079', 0.3081616733674219), ('4045', 0.3064774696349292), ('1062', 0.3030812011656654), ('2653', 0.29867259384800815), ('2135', 0.294239354413226), ('2700', 0.2919760143726594), ('1922', 0.29078270571126924), ('1470', 0.29053215415053657), ('5524', 0.28933963806677543), ('1395', 0.28898666372523385), ('2686', 0.2880552610935442), ('1492', 0.2878566102100926), ('2842', 0.28534693130296446), ('2256', 0.28524746472320145), ('319', 0.2848051389918796), ('2660', 0.2840213897015501), ('6', 0.28346966379895455), ('3454', 0.28331501985031227), ('312', 0.277895069758437), ('3642', 0.27641571156992617), ('3614', 0.273935812309728), ('663', 0.27159679234495726), ('2674', 0.2703715582954867), ('2790', 0.27009589666146466), ('3615', 0.2673364853084692), ('1055', 0.2664638699465996), ('1428', 0.2637449689740948), ('2693', 0.2625787213684411), ('87', 0.2625497152766452), ('769', 0.26165939504463365), ('1808', 0.2611350503440403), ('432', 0.2609472157937457), ('4310', 0.2588923554756584), ('634', 0.2529965889953349), ('1167', 0.2490917242556255), ('2145', 0.24841761520885425), ('72', 0.24834139909423217), ('5189', 0.24810515233840352), ('2229', 0.2467319388101919), ('3010', 0.24649496692490316)]
# ====================================================================================================
# [('2565', 893346.3492410672), ('1549', 838174.4311656053), ('15', 585088.6761779548), ('72', 405413.2984052525), ('737', 310442.3953302085), ('1166', 293619.79024072277), ('5079', 275184.7021313253), ('2328', 263248.5680348247), ('2237', 238579.1142274329), ('28', 230946.61097836684), ('993', 220309.09510728705), ('3352', 219229.20580178488), ('2658', 201818.30627178669), ('3456', 201174.88644320474), ('8', 200139.81056959438), ('5524', 195148.13098142992), ('4037', 192353.72019108507), ('762', 184420.02156902672), ('2398', 183722.86407240728), ('2485', 175051.56575336168), ('2651', 169890.77044885248), ('3976', 167784.60408473882), ('4310', 161180.36641106085), ('600', 157379.30511640385), ('5022', 155789.87743222847), ('2871', 150821.63485610843), ('825', 150770.35949104434), ('1374', 145683.77864249615), ('4828', 140376.35747086524), ('5179', 139834.95951459988), ('1352', 138736.83814751345), ('1297', 137379.79056203982), ('4099', 137299.18152952846), ('1151', 132579.8292731208), ('5800', 125596.8247406333), ('1305', 120900.78137724), ('789', 120406.21813872566), ('6946', 120137.78513110601), ('3459', 118010.38805002384), ('4712', 117134.60096666959), ('56', 116155.27162951129), ('2256', 115206.90328495545), ('5697', 113437.07686100915), ('5543', 111404.29944969986), ('407', 110548.2972921811), ('2576', 105694.64056064171), ('1211', 104367.59271335593), ('2654', 102488.63206542657), ('1608', 102206.23107077875), ('3028', 101707.48603330327), ('2940', 99282.65112347476), ('6914', 98525.57472140364), ('5002', 98224.42765129595), ('3453', 98153.19129644705), ('2790', 94737.69675287415), ('3447', 92856.47813267804), ('5189', 91713.00865098381), ('5020', 91405.29137937266), ('86', 90384.1877443821), ('2535', 85735.73075308117), ('55', 85094.83180258321), ('7092', 82140.17158431481), ('6', 79581.19383628255), ('633', 79118.55452470735), ('5814', 78249.54720233727), ('3568', 77391.44185076401), ('5254', 77332.57262548953), ('1473', 76868.15219776196), ('722', 76277.23532324829), ('2972', 76038.23042447805), ('2323', 75855.08156185201), ('4536', 75231.8742212819), ('35', 73566.1165606352), ('3498', 72978.0829323567), ('2285', 72239.00971988992), ('3586', 69342.69789523291), ('4632', 68971.77334444826), ('2660', 67328.55509795959), ('4653', 67282.07437591907), ('665', 65853.2959686475), ('6327', 65644.43863776531), ('663', 65601.3388449292), ('2120', 65390.76660417235), ('3026', 64962.375414038266), ('6774', 64003.16009017278), ('3631', 63436.44504013304), ('1717', 62113.76148731446), ('4191', 61812.091896447724), ('1496', 61359.320162183496), ('1357', 60955.73087858044), ('6618', 60392.22596428405), ('2145', 60178.77143566562), ('5806', 59849.09698126961), ('2859', 58378.79359600127), ('4483', 57948.21509249351), ('2504', 57511.44203432628), ('1919', 56881.7806939569), ('4335', 56311.724508051404), ('3084', 56258.03520718281), ('2686', 55882.88733190306)]
